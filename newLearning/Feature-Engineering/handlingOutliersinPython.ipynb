# %%
import numpy as np 
list=[-34,3,4,5,56,6,75,7,6,75,32,11,43,102]
mininmum,Q1,median,Q2,maximum=np.quantile(list,[0,.25,.5,.75,1])

# %%
mininmum,Q1,median,Q2,maximum
# Out:
# (np.float64(3.0),
#  np.float64(5.75),
#  np.float64(9.0),
#  np.float64(46.25),
#  np.float64(75.0))

# %%
IQR=Q2-Q1
print(IQR)
# Out:
# 40.5

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q1+1.5*(IQR)
print(lower_fence,higher_fence)
# here we have the lowe and higer outliers that we  have if out of this then it 
# will show im boxPlot the diffß
# Out:
# -55.0 66.5

# %%
import seaborn as sns
sns.boxplot(list)
# Out:
# <Axes: >
