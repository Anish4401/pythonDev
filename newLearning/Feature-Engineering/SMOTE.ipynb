# %%
# !pip3 install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (31 kB)
# ...
#   Using cached scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (60 kB)
# ...
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# ...

# %%
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_samples=1000,n_features=2,n_redundant=0,n_clusters_per_class=1 ,
weights=[.92],random_state=12)

# %%
import pandas as pd 
df=pd.DataFrame(X,columns=['f1','f2'])
df1=pd.DataFrame(y,columns=['target'])
final_df=pd.concat([df1,df],axis=1)

# %%
final_df.target.value_counts()
# Out:
# target
# 0    920
# 1     80
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %%
# !pip3 install imblearn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [imblearn]
# ...

# %%
from imblearn.over_sampling import SMOTE

# %%
oversmaple=SMOTE()
X,y=oversmaple.fit_resample(final_df[['f1','f2']],final_df['target'])
# Out:
# /Users/anish/Documents/dev/pythonDev/.venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %%
X.shape
# Out:
# (1840, 2)

# %%
y.shape
# Out:
# (1840,)

# %%
y[y==0]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: target, Length: 920, dtype: int64

# %%
len(y[y==0])
# Out:
# 920

# %%
len(y[y==1])
# Out:
# 920

# %%
import pandas as pd 
df=pd.DataFrame(X,columns=['f1','f2'])
df1=pd.DataFrame(y,columns=['target'])
overide_final_df=pd.concat([df1,df],axis=1)

# %%
plt.scatter(overide_final_df['f1'],overide_final_df['f2'],c=overide_final_df['target'])
# here we can clerarly see the the point of the 80 is increase to same as 920 and scattered c
# connecting the two points
